# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
DATADIR = r"C:\Users\G.VENKATARAMANA\test1\train"
CATEGORIES = ["dog","cat"]

# %%
for categories in CATEGORIES:
        path = os.path.join(DATADIR,categories)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
            plt.imshow(img_array,cmap='gray')
            plt.show()
            break
        break

# %%
newarray = cv2.resize(img_array,(80,80))
plt.imshow(newarray,cmap = 'gray')
plt.show()

# %%
trainingdata = []
def createtrainingdata():
        for categories in CATEGORIES:
            path = os.path.join(DATADIR,categories)
            classnum = CATEGORIES.index(categories)
            for img in os.listdir(path):
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                newarray = cv2.resize(img_array,(80,80))
                
                trainingdata.append([newarray , classnum])

# %%
createtrainingdata()

# %%
n= len(trainingdata[])
# Out:
#   File "<ipython-input-7-634e5959cf3a>", line 1
#     n= len(trainingdata[])
#                         ^
# SyntaxError: invalid syntax

# %%
n
