# %%
import numpy as np
import random

# %%
arr = np.random.normal(1,10,10000)

# %%
mean = np.mean(arr)
median = np.median(arr)

# %%
print(mean)
# Out:
# 1.0761205412731096

# %%
print(median)
# Out:
# 1.0211646753282593

# %%
for i in arr:
    print(i)
print(f"sum is:",sum(arr))
# Out:
# -3.988199891955955
# -10.867034149888479
# -12.737117948343737
# 3.142385838416794
# -10.184600877562067
# -21.07951768276689
# 18.581015340877858
# -18.853560716181494
# -3.8757777604181243
# 4.465076017967585
# 1.9976265223405731
# -12.412556845780168
# -2.989079193047801
# 5.227029035762202
# 2.9190465044687643
# -8.772213743982569
# 6.229838564667125
# -3.2404021035766446
# -6.60573075112822
# 17.675184009533154
# -4.806882119353216
# -10.90700681933077
# -4.38386322352526
# 7.344155969473859
# -2.4840393567931462
# -8.669046748252185
# -6.57003377404169
# 4.283649437518678
# 8.631551879169876
# -1.455898151287585
# -1.140467151860733
# 6.462961576483244
# 10.165955345468982
# 5.091419432409974
# -19.304561599138143
# 7.612307686971288
# 0.6652015772633609
# -6.746796957848324
# 0.40592968363038384
# 4.590727855002491
# -0.08261210392011309
# 2.364990408505671
# -2.069453084127605
# -6.943029672319591
# -0.6718467193553614
# -1.2354363426935375
# -8.388935497424578
# ...

# %%
import statistics

# %%
mode = statistics.mode(arr)
# Out:
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-60-b5ea6a3cacf5> in <module>
# ----> 1 mode = statistics.mode(arr)
#
# ~\Anaconda3\lib\statistics.py in mode(data)
#     504     elif table:
#     505         raise StatisticsError(
# --> 506                 'no unique mode; found %d equally common values' % len(table)
#     507                 )
#     508     else:
#
# StatisticsError: no unique mode; found 10000 equally common values

# %%
range = max(arr)-min(arr)

# %%
range
# Out:
# 71.88728229423491

# %%
import matplotlib.pyplot as plt

# %%
line = plt.plot(arr)
