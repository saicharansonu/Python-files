# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\G.VENKATARAMANA\DataSets\1\test.csv')

# %%
data
# Out:
#      Id     1     2     3     4      5     6     7
# 0     1  0.03  0.12   NaN   NaN    NaN   NaN   NaN
# 1     2  0.15  0.06   NaN   NaN    NaN   NaN   NaN
# 2    32  0.04  0.00   NaN   NaN    NaN   NaN   NaN
# 3    40  0.10  0.14   NaN   NaN    NaN   NaN   NaN
# 4    43  0.09  0.10   NaN   NaN    NaN   NaN   NaN
# 5    46  0.36  0.48   NaN   NaN    NaN   NaN   NaN
# 6    53  0.28  0.35   NaN   NaN    NaN   NaN   NaN
# 7    60  0.52  0.52  0.12  0.68   0.14   NaN   NaN
# 8    61  0.26  0.26   NaN   NaN    NaN   NaN   NaN
# 9    68  0.05  0.06  0.67  1.12   0.90   NaN   NaN
# 10   71  0.14  0.15  0.03  0.67    NaN   NaN   NaN
# 11   74  0.44  0.34   NaN   NaN    NaN   NaN   NaN
# 12   78  0.16  0.34   NaN   NaN   1.01   NaN   NaN
# 13   80  0.20  0.34  0.60  2.22   0.15  1.78  0.10
# 14   81  0.26  0.16   NaN   NaN    NaN  0.90   NaN
# 15   84  0.10  0.06  0.41  0.12    NaN   NaN   NaN
# 16   85  0.23  0.22   NaN   NaN   0.30  0.14   NaN
# ...
